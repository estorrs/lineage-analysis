# %%
import os
import re

import pandas as pd
import numpy as np

import mgitools.os_helpers as os_helpers

# %% [markdown]
# ## metadata reformatting

# %%
metadata_df = pd.read_csv('../data/metadata/PV_CyTOF_metadata.csv', sep=',')

print(metadata_df.shape)
metadata_df.head()
# Out:
# (50, 13)
#    EXP_DATE                 CONDITION_LIST AGE_YEARS JAK2_BURDEN_PERCENTAGE  \
# 0    160113                     basal, TNF        47                      0
# 1    160113                     basal, TNF        43                   39.9
# 2    160113                     basal, TNF        68                  92.24
# 3    160727  basal, TPO, TNF, RUX, TPO+RUX   unknown                      0
# 4    160727  basal, TPO, TNF, RUX, TPO+RUX        30                      0
#
#        SEX SAMPLE_TYPE SAMPLE_NAME CD16_FAIL TNF_FAIL_OR_ABSENT  \
# 0        F         NBM      N23 BM        NO                 NO
# 1        M        PVPB   638517 PB        NO                 NO
# 2        M        PVPB   673286 PB        NO                 NO
# 3  unknown         NPB    LRS1 NPB        NO                 NO
# 4        F         NBM      N24 BM        NO                 NO
#
#   TPO_FAIL_OR_ABSENT  DUPLICATE_PATIENT_SAMPLETYPE  \
# 0                YES                           NaN
# 1                YES                           NaN
# 2                YES                           NaN
# 3                 NO                           NaN
# 4                 NO                           NaN
#
#    SAME_COLLECTION_SAMPLETYPE_PAIRS  TRANSFORMATION_PAIRS
# 0                               NaN                   NaN
# 1                              10.0                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN

# %% [markdown]
# make sample ids where the id is in the format samplename_sampletype_expdate_condition

# %%
np.asarray(data)
# Out:
# array([[160113, 'basal, TNF', '47', ..., nan, nan, nan],
#        [160113, 'basal, TNF', '47', ..., nan, nan, nan],
#        [160113, 'basal, TNF', '43', ..., nan, 10.0, nan],
#        ...,
#        [190726, 'basal, TPO, TNF', '41', ..., nan, nan, nan],
#        [190726, 'basal, TPO, TNF', '41', ..., nan, nan, nan],
#        [190726, 'basal, TPO, TNF', '41', ..., nan, nan, nan]],
#       dtype=object)

# %%
metadata_df['SAMPLE_NAME'] = [x.replace(' ', '-').replace('.', '-').replace('_', '-')
            for x in metadata_df['SAMPLE_NAME']]

data = []
sample_ids = []
for i, row in metadata_df.iterrows():
#     row.values
    conditions = row['CONDITION_LIST']
    for condition in re.split(r',|, *', conditions.strip()):
        condition = condition.strip()
        data.append(row.values)
        sample_name, sample_type, exp_date = (row['SAMPLE_NAME'], row['SAMPLE_TYPE'], row['EXP_DATE'])
        sample_ids.append(f'{sample_name}_{sample_type}_{exp_date}_{condition}'.replace(' ', '-'))
        
data = np.asarray(data)
data[data == 'unknown'] = np.nan

df = pd.DataFrame(data=np.asarray(data), index=sample_ids, columns=metadata_df.columns)
df.columns = [c if c != 'CONDITION_LIST' else 'CONDITION' for c in df.columns]
df['CONDITION'] = [x.split('_')[-1] for x in df.index]
df['EXP_DATE'] = [str(x) for x in df['EXP_DATE']]

# ## normalize sample names
# sample_name_to_possibles = {x.replace(' ', '-').replace('.', '-').replace('_', '-'):set() for x in df['SAMPLE_NAME']}
# for sample_name in df['SAMPLE_NAME']:
#     orig = sample_name
#     sample_name = sample_name.replace(' ', '-').replace('.', '-').replace('_', '-')
    
#     possibles = [orig]
#     possibles.append(sample_name.replace('-', ' '))
#     possibles.append(sample_name.replace('-', '_'))
    
#     ## also shuffle
#     pieces = sample_name.split('-')
#     possibles.append(' '.join(pieces[-1:] + pieces[:-1]))
#     possibles.append('-'.join(pieces[-1:] + pieces[:-1]))
#     possibles.append('_'.join(pieces[-1:] + pieces[:-1]))
    
    
#     sample_name_to_possibles[sample_name].update(possibles)

df.head()
# Out:
#                             EXP_DATE CONDITION AGE_YEARS  \
# N23-BM_NBM_160113_basal       160113     basal        47
# N23-BM_NBM_160113_TNF         160113       TNF        47
# 638517-PB_PVPB_160113_basal   160113     basal        43
# 638517-PB_PVPB_160113_TNF     160113       TNF        43
# 673286-PB_PVPB_160113_basal   160113     basal        68
#
#                             JAK2_BURDEN_PERCENTAGE SEX SAMPLE_TYPE  \
# N23-BM_NBM_160113_basal                          0   F         NBM
# N23-BM_NBM_160113_TNF                            0   F         NBM
# 638517-PB_PVPB_160113_basal                   39.9   M        PVPB
# 638517-PB_PVPB_160113_TNF                     39.9   M        PVPB
# 673286-PB_PVPB_160113_basal                  92.24   M        PVPB
#
#                             SAMPLE_NAME CD16_FAIL TNF_FAIL_OR_ABSENT  \
# N23-BM_NBM_160113_basal          N23-BM        NO                 NO
# N23-BM_NBM_160113_TNF            N23-BM        NO                 NO
# 638517-PB_PVPB_160113_basal   638517-PB        NO                 NO
# 638517-PB_PVPB_160113_TNF     638517-PB        NO                 NO
# 673286-PB_PVPB_160113_basal   673286-PB        NO                 NO
#
#                             TPO_FAIL_OR_ABSENT DUPLICATE_PATIENT_SAMPLETYPE  \
# N23-BM_NBM_160113_basal                    YES                          NaN
# N23-BM_NBM_160113_TNF                      YES                          NaN
# 638517-PB_PVPB_160113_basal                YES                          NaN
# 638517-PB_PVPB_160113_TNF                  YES                          NaN
# 673286-PB_PVPB_160113_basal                YES                          NaN
#
#                             SAME_COLLECTION_SAMPLETYPE_PAIRS  \
# N23-BM_NBM_160113_basal                                  NaN
# N23-BM_NBM_160113_TNF                                    NaN
# 638517-PB_PVPB_160113_basal                               10
# 638517-PB_PVPB_160113_TNF                                 10
# 673286-PB_PVPB_160113_basal                              NaN
#
#                             TRANSFORMATION_PAIRS
# N23-BM_NBM_160113_basal                      NaN
# N23-BM_NBM_160113_TNF                        NaN
# 638517-PB_PVPB_160113_basal                  NaN
# 638517-PB_PVPB_160113_TNF                    NaN
# 673286-PB_PVPB_160113_basal                  NaN

# %%
# sample_name_to_possibles

# %% [markdown]
# ## map to cytof .fcs files

# %%
fdc_fps = sorted(os_helpers.listfiles('/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/', regex='.fcs'))
len(fdc_fps), fdc_fps[:5]
# Out:
# (10,
#  ['/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/190621 JF Oh Human Myeloid N39-PB TNF.fcs',
#   '/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/190712 JF Oh Human Myeloid_N37-PB basal.fcs',
#   '/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/190712 JF Oh Human Myeloid_N38-PB basal.fcs',
#   '/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/190726 JF Oh Human Myeloid_336362-PB TPO.fcs',
#   '/Users/estorrs/Documents/steveoh/lineage_analysis/data/cytof/190726 JF Oh Human Myeloid_646192-BM TNF.fcs'])

# %%
def get_fp_data(fcs_fp):
    """returns a tup with the following positions: exp_date, condition, sample_name, condition"""
    fp = fcs_fp.split('/')[-1]
    
    exp_date = re.sub(r'^([0-9]+).*$', r'\1', fp)
    condition = re.sub(r'^.*[ |_](.*)\.fcs', r'\1', fp)
    sample_name = re.sub(r'^.*Human Myeloid[ |_](.+) .*$', r'\1', fp)
    
    return exp_date, condition, sample_name

# %%
tup_to_filepath = {}
for fp in fdc_fps:
    exp_date, condition, sample_name = get_fp_data(fp)
    tup_to_filepath[(exp_date, condition, sample_name)] = fp
#     print()
#     print((exp_date, condition, sample_name))

## add fp column to metadata
filepaths = []
for i, row in df.iterrows():
#     print((row['EXP_DATE'], row['CONDITION'], row['SAMPLE_NAME']))
#     print(tup_to_filepath.get((row['EXP_DATE'], row['CONDITION'], row['SAMPLE_NAME']), np.nan))
    filepaths.append(tup_to_filepath.get((row['EXP_DATE'], row['CONDITION'], row['SAMPLE_NAME']), np.nan))

df['filepath'] = filepaths
        
df
# Out:
#                             EXP_DATE CONDITION AGE_YEARS  \
# N23-BM_NBM_160113_basal       160113     basal        47
# N23-BM_NBM_160113_TNF         160113       TNF        47
# 638517-PB_PVPB_160113_basal   160113     basal        43
# 638517-PB_PVPB_160113_TNF     160113       TNF        43
# 673286-PB_PVPB_160113_basal   160113     basal        68
# ...                              ...       ...       ...
# 646192-BM_PVBM_190726_TPO     190726       TPO        52
# 646192-BM_PVBM_190726_TNF     190726       TNF        52
# N35-BM_NBM_190726_basal       190726     basal        41
# N35-BM_NBM_190726_TPO         190726       TPO        41
# N35-BM_NBM_190726_TNF         190726       TNF        41
#
#                             JAK2_BURDEN_PERCENTAGE SEX SAMPLE_TYPE  \
# N23-BM_NBM_160113_basal                          0   F         NBM
# N23-BM_NBM_160113_TNF                            0   F         NBM
# 638517-PB_PVPB_160113_basal                   39.9   M        PVPB
# 638517-PB_PVPB_160113_TNF                     39.9   M        PVPB
# 673286-PB_PVPB_160113_basal                  92.24   M        PVPB
# ...                                            ...  ..         ...
# 646192-BM_PVBM_190726_TPO                       42   M        PVBM
# 646192-BM_PVBM_190726_TNF                       42   M        PVBM
# N35-BM_NBM_190726_basal                          0   F         NBM
# N35-BM_NBM_190726_TPO                            0   F         NBM
# N35-BM_NBM_190726_TNF                            0   F         NBM
#
#                             SAMPLE_NAME CD16_FAIL TNF_FAIL_OR_ABSENT  \
# N23-BM_NBM_160113_basal          N23-BM        NO                 NO
# N23-BM_NBM_160113_TNF            N23-BM        NO                 NO
# 638517-PB_PVPB_160113_basal   638517-PB        NO                 NO
# 638517-PB_PVPB_160113_TNF     638517-PB        NO                 NO
# 673286-PB_PVPB_160113_basal   673286-PB        NO                 NO
# ...                                 ...       ...                ...
# 646192-BM_PVBM_190726_TPO     646192-BM        NO                 NO
# 646192-BM_PVBM_190726_TNF     646192-BM        NO                 NO
# N35-BM_NBM_190726_basal          N35-BM        NO                 NO
# N35-BM_NBM_190726_TPO            N35-BM        NO                 NO
# N35-BM_NBM_190726_TNF            N35-BM        NO                 NO
#
#                             TPO_FAIL_OR_ABSENT DUPLICATE_PATIENT_SAMPLETYPE  \
# N23-BM_NBM_160113_basal                    YES                          NaN
# N23-BM_NBM_160113_TNF                      YES                          NaN
# 638517-PB_PVPB_160113_basal                YES                          NaN
# 638517-PB_PVPB_160113_TNF                  YES                          NaN
# 673286-PB_PVPB_160113_basal                YES                          NaN
# ...                                        ...                          ...
# 646192-BM_PVBM_190726_TPO                   NO                          NaN
# 646192-BM_PVBM_190726_TNF                   NO                          NaN
# N35-BM_NBM_190726_basal                     NO                          NaN
# N35-BM_NBM_190726_TPO                       NO                          NaN
# N35-BM_NBM_190726_TNF                       NO                          NaN
#
#                             SAME_COLLECTION_SAMPLETYPE_PAIRS  \
# N23-BM_NBM_160113_basal                                  NaN
# N23-BM_NBM_160113_TNF                                    NaN
# 638517-PB_PVPB_160113_basal                               10
# 638517-PB_PVPB_160113_TNF                                 10
# 673286-PB_PVPB_160113_basal                              NaN
# ...                                                      ...
# 646192-BM_PVBM_190726_TPO                                NaN
# 646192-BM_PVBM_190726_TNF                                NaN
# N35-BM_NBM_190726_basal                                  NaN
# N35-BM_NBM_190726_TPO                                    NaN
# N35-BM_NBM_190726_TNF                                    NaN
#
#                             TRANSFORMATION_PAIRS  \
# N23-BM_NBM_160113_basal                      NaN
# N23-BM_NBM_160113_TNF                        NaN
# 638517-PB_PVPB_160113_basal                  NaN
# 638517-PB_PVPB_160113_TNF                    NaN
# 673286-PB_PVPB_160113_basal                  NaN
# ...                                          ...
# 646192-BM_PVBM_190726_TPO                    NaN
# 646192-BM_PVBM_190726_TNF                    NaN
# N35-BM_NBM_190726_basal                      NaN
# N35-BM_NBM_190726_TPO                        NaN
# N35-BM_NBM_190726_TNF                        NaN
#
#                                                                       filepath
# N23-BM_NBM_160113_basal                                                    NaN
# N23-BM_NBM_160113_TNF                                                      NaN
# 638517-PB_PVPB_160113_basal                                                NaN
# 638517-PB_PVPB_160113_TNF                                                  NaN
# 673286-PB_PVPB_160113_basal                                                NaN
# ...                                                                        ...
# 646192-BM_PVBM_190726_TPO    /Users/estorrs/Documents/steveoh/lineage_analy...
# 646192-BM_PVBM_190726_TNF    /Users/estorrs/Documents/steveoh/lineage_analy...
# N35-BM_NBM_190726_basal      /Users/estorrs/Documents/steveoh/lineage_analy...
# N35-BM_NBM_190726_TPO        /Users/estorrs/Documents/steveoh/lineage_analy...
# N35-BM_NBM_190726_TNF        /Users/estorrs/Documents/steveoh/lineage_analy...
#
# [153 rows x 14 columns]

# %%
df.to_csv('../data/metadata/metadata_reformatted.tsv', sep='\t', index=True, header=True)
